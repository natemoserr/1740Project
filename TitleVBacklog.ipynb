# %%
import pandas as pd

df = pd.read_csv("TitleVPermitData.csv")
df.head()
# Out:
#          Region    County              Municipality  \
# 0  Northcentral  Bradford           Asylum Township
# 1  Northcentral  Bradford    North Towanda Township
# 2  Northcentral  Bradford             Sayre Borough
# 3  Northcentral  Bradford  West Burlington Township
# 4  Northcentral  Bradford            Wysox Township
#
#                           Client               Site Name  Site ID  \
# 0           HAMILTON LIBERTY LLC    HAMILTON LIBERTY LLC   753377
# 1  DUPONT SPECIALTY PROD USA LLC           QNITY TOWANDA   249437
# 2                RYNONE MFG CORP              RYNONE MFG     2854
# 3              NORTHERN TIER SWA    BRADFORD CNTY LDFL 2   242356
# 4                  WOODGRAIN INC  WOODGRAIN FIBER DIV PA   259347
#
#                                      PF Name   PF ID Active Facility  \
# 0  HAMILTON LIBERTY LLC/HAMILTON LIBERTY LLC  745923               Y
# 1          QNITY ELECTRONICS INC/TOWANDA PLT  256580               Y
# ...
